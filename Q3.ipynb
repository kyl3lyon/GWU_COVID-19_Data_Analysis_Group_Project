# %%
from IPython.display import Image
Image("Pct Positive Antigen vs Viral.png")

# %%
from IPython.display import Image
Image("Qty Antigen vs Viral.png")

# %% [markdown]
# From just looking, we can observe that the percentage of viral tests taken far outpaces antigen tests. That is to say, in most states, about 80% of tests administered were viral tests. Statistically, this discrepancy can affect positivity rates as the more viral tests are administered, the higher the chance for viral test positivity. In states where both antigen and viral tests are available, we can see mixed results state to state. In 7 out of 12 states, viral positivity is greater than antigen positivity by 2% or more. Antigen test positivity is greater than viral test positivity in two states. Further statistical testing is needed to explain the difference between antigen positives and viral positives from state to state. Still, based on the information provided now, we can conclude viral testing leads to increased positivity rates.
